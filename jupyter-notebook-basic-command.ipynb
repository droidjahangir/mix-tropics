# %% [markdown]
# # Add images

# %% [markdown]
# ## 4 method to add images
#
# ### Method - 1

# %% [markdown]
# ![title](./images/systemOfLinearEquation.png)

# %%
from IPython.display import Image
Image(filename = "./images/systemOfLinearEquation2.png",width = 400, height = 400)

# %% [markdown]
# ### অন্যান্য মেথড গুলো php ফর্ম এ, সেজন্য বাকিগুলো দেখানো হয় নি ( আপাতত আমাদের PHP ফর্ম গুলো লাগছে না )

# %% [markdown]
# # Superscript & Subscript

# %% [markdown]
# ### Latex subscript:
#
# $x_{2}$

# %% [markdown]
# ### Latex superscript:
#
# $x^{2}$
